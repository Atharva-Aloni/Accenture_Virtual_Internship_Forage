# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Dataset/Content.csv')

# %%
df
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Category', 'URL'], dtype='object')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True,axis=1)

# %%
df
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo       technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video             food
# ...

# %%
df.dtypes
# Out:
# Content ID    object
# User ID       object
# Type          object
# Category      object
# URL           object
# dtype: object

# %%
df.isna().sum()
# Out:
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
df
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
# ...

# %%
df.to_csv('clean_content.csv')

# %%
df = pd.read_csv('../Dataset/Reactions.csv')

# %%
df
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True,axis=1)

# %%
df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# ...

# %%
df.columns
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')

# %%
df.dtypes
# Out:
# Content ID    object
# User ID       object
# Type          object
# Datetime      object
# dtype: object

# %%
df['Datetime'] = df['Datetime'].astype('datetime64[ns]')

# %%
df.dtypes
# Out:
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
df
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 0                                       NaN         NaN 2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# ...

# %%
df.isna().sum()
# Out:
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#                                  Content ID  \
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 5      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type            Datetime
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust 2020-11-07 09:43:50
# 2      92b87fa5-f271-43e0-af66-84fac21052e6     dislike 2021-06-17 12:22:51
# 3      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared 2021-04-18 05:13:58
# 4      34e8add9-0206-47fd-a501-037b994650a2     disgust 2021-01-06 19:13:01
# ...

# %%
df.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
df.dtypes
# Out:
# Content ID            object
# User ID               object
# Type                  object
# Datetime      datetime64[ns]
# dtype: object

# %%
df.to_csv('clean_reaction.csv')

# %%
df = pd.read_csv('../Dataset/ReactionTypes.csv')

# %%
df
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
df.drop(columns=['Unnamed: 0'],inplace=True,axis=1)

# %%
df
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
df.dtypes
# Out:
# Type         object
# Sentiment    object
# Score         int64
# dtype: object

# %%
df.isna().sum()
# Out:
# Type         0
# Sentiment    0
# Score        0
# dtype: int64

# %%
df.to_csv('clean_ReactionType.csv')

# %%
d_content = pd.read_csv('clean_content.csv')

# %%
d_content.isna().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Category      0
# URL           0
# dtype: int64

# %%
d_content=d_content.drop(columns=['Unnamed: 0'],axis=1)

# %%
d_content
# Out:
#                                Content ID  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3    356fff80-da4d-4785-9f43-bc1261031dc6
# 4    01ab84dd-6364-4236-abbb-3f237db77180
# ..                                    ...
# 796  c54b49c4-b1f2-4641-8595-1cbd19937845
# 797  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 798  435007a5-6261-4d8b-b0a4-55fdc189754b
# 799  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 800  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3    9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4    e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
# ...

# %%
d_reaction_type = pd.read_csv('clean_ReactionType.csv')

# %%
d_reaction_type
# Out:
#     Unnamed: 0         Type Sentiment  Score
# 0            0        heart  positive     60
# 1            1         want  positive     70
# 2            2      disgust  negative      0
# 3            3         hate  negative      5
# 4            4   interested  positive     30
# 5            5  indifferent   neutral     20
# 6            6         love  positive     65
# 7            7   super love  positive     75
# 8            8      cherish  positive     70
# 9            9        adore  positive     72
# 10          10         like  positive     50
# 11          11      dislike  negative     10
# 12          12    intrigued  positive     45
# 13          13      peeking   neutral     35
# 14          14       scared  negative     15
# 15          15      worried  negative     12

# %%
d_reaction_type = d_reaction_type.drop(columns=['Unnamed: 0'],axis=1)

# %%
d_reaction_type
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
d_reaction = pd.read_csv('clean_reaction.csv')

# %%
d_reaction
# Out:
#        Unnamed: 0                            Content ID  \
# 0               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 22529       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22530       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22531       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22532       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22533       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 1      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# ...

# %%
d_reaction = d_reaction.drop(columns=['Unnamed: 0'],axis=1)

# %%
print(d_content.columns)
print(d_reaction.columns)
print(d_reaction_type.columns)
# Out:
# Index(['Content ID', 'User ID', 'Type', 'Category', 'URL'], dtype='object')
# Index(['Content ID', 'User ID', 'Type', 'Datetime'], dtype='object')
# Index(['Type', 'Sentiment', 'Score'], dtype='object')

# %%
d_content_temp = d_content[['Content ID','Category','URL']]

# %%
d_content_temp
# Out:
#                                Content ID        Category  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2        Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6      technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180            food
# ..                                    ...             ...
# 796  c54b49c4-b1f2-4641-8595-1cbd19937845         science
# 797  7a79f4e4-3b7d-44dc-bdef-bc990740252c      technology
# 798  435007a5-6261-4d8b-b0a4-55fdc189754b        veganism
# 799  4e4c9690-c013-4ee7-9e66-943d8cbd27b7         culture
# 800  75d6b589-7fae-4a6d-b0d0-752845150e56      technology
#
#                                                    URL
# 0    https://socialbuzz.cdn.com/content/storage/975...
# 1    https://socialbuzz.cdn.com/content/storage/9f7...
# 2    https://socialbuzz.cdn.com/content/storage/230...
# ...

# %%
d_reaction_type_temp = d_reaction_type[['Type','Sentiment','Score']]

# %%
new_final=pd.merge(d_reaction,d_content_temp,on='Content ID')

# %%
new_final
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 1      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 2      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 3      34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# ...

# %%
new_final.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# Category      0
# URL           0
# dtype: int64

# %%
new_final = pd.merge(new_final,d_reaction_type_temp,on='Type')

# %%
new_final.dtypes
# Out:
# Content ID    object
# User ID       object
# Type          object
# Datetime      object
# Category      object
# URL           object
# Sentiment     object
# Score          int64
# dtype: object

# %%
new_final.isna().sum()
# Out:
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# Category      0
# URL           0
# Sentiment     0
# Score         0
# dtype: int64

# %%
new_final
# Out:
#                                  Content ID  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...                                     ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime  \
# 0      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# 1      92b87fa5-f271-43e0-af66-84fac21052e6     dislike  2021-06-17 12:22:51
# 2      163daa38-8b77-48c9-9af6-37a6c1447ac2      scared  2021-04-18 05:13:58
# 3      34e8add9-0206-47fd-a501-037b994650a2     disgust  2021-01-06 19:13:01
# ...

# %%
new_final.to_csv('Final_Cleaned_dataset_Task1.csv')

# %%
new_final.tail()
# Out:
#                                  Content ID  \
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID       Type             Datetime  \
# 18379  b6d04982-1509-41ab-a700-b390d6cb4d02    worried  2020-10-31 04:50:14
# 18380  80c9ce48-46f9-4f5e-b3ca-3b698fc2e949    dislike  2020-06-27 09:46:48
# 18381  2bd9c167-e06c-47c1-a978-3403d6724606  intrigued  2021-02-16 17:17:02
# 18382  5ffd8b51-164e-47e2-885e-8b8c46eb63ed    worried  2020-11-04 20:08:31
# 18383  4edc3d1a-a7d9-4db6-89c3-f784d9954172    cherish  2021-01-04 04:55:11
#
#          Category                                                URL  \
# 18379  technology  https://socialbuzz.cdn.com/content/storage/75d...
# 18380  technology  https://socialbuzz.cdn.com/content/storage/75d...
# ...
